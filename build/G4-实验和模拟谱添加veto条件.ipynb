// %% [markdown]
// 为了和实验上进行对照，应该在模拟上添加veto探测器。设置模拟veto的预制为400keV。

// %% [markdown]
// ### 质子峰宽度调整

// %%
%jsroot on
TFile *s1=new TFile("simu0802.root");
TCanvas c1;

// %%
tree->Draw("de[2][0]*1000>>p2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&de[3][0]+de[3][1]<0.4");
tree->Draw("de[2][1]*1000>>b2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&de[3][0]+de[3][1]<0.4");

tree->Draw("(de[2][0]+de[2][1])*1000>>bp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&de[3][0]+de[3][1]<0.4");
tree->Draw("(de[2][0]+de[2][1])*1000>>brp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][1]>0&&de[3][0]+de[3][1]<0.4");
tree->Draw("(de[2][0]+de[2][1])*1000>>blp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][1]<=0&&de[3][0]+de[3][1]<0.4");

// %% [markdown]
// 下图中，蓝线为后Si的质子单谱，黑线为后Si的质子+beta叠加谱。

// %%
c1.Clear();
bp2_001->SetLineColor(1);
p2_001->Draw();
bp2_001->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %% [markdown]
// ### 载入实验谱

// %%
TFile *s2=new TFile("al.root");

// %%
c1.Clear();
s1->cd();
bp2_001->Scale(0.01875);
bp2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_2"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %% [markdown]
// 上图中，蓝线为实验谱(veto<200),黑线为模拟谱(veto<400keV)。添加veto探测器后，明显伴峰得到了消除。注意1.3MeV处的质子峰，相比未添加质子峰，更贴近于实验。但高能区(3000,3200,3500,4200)无法吻合。与先前不卡veto条件的对比结构一致。

// %% [markdown]
// ### 附谱(备忘)

// %% [markdown]
// 下图中实线为实验谱，虚线为实验质子单谱。

// %%
c1.Clear();
s1->cd();
p2_001->Scale(0.006667);
p2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_3"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %% [markdown]
// 下图中实线为实验谱，虚线为实验质子+向右逃逸的beta叠加谱。

// %%
c1.Clear();
s2->cd();
al2->Draw();
s1->cd();
brp2_001->Scale(0.015);
brp2_001->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_4"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %% [markdown]
// 下图中实线为实验谱，虚线为实验质子+向左逃逸的beta叠加谱。

// %%
c1.Clear();
s1->cd();
blp2_001->Scale(0.01935);
blp2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_5"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...
