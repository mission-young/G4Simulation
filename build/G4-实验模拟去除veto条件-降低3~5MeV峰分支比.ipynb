// %% [markdown]
// 先前的处理中，3~5MeV附近的模拟质子计数较高，与实验谱不能得到较好的对照。因而这里尝试降低3~5MeV的分支比。

// %% [markdown]
// ### 调整分支比

// %%
%jsroot on
double f1(double x)
{
    double energy[25] = {475, 721, 975, 1033, 1223, 1299, 1551, 1753, 2072, 2503, 2583, 2838, 3088, 3484, 4017, 4224, 4464, 4912, 5177, 5667, 5808, 5909, 6085, 6774, 7517};
    double br[25] = {4.73, 7.39, 0.25, 3, 0.75, 18.51, 0.81, 0.45, 0.48, 0.64, 4.89, 2.11, 1.89/4, 2.18/4, 1.078/4, 0.84/4, 3.21/4, 0.27/4, 0.29, 0.35, 0.18, 0.21, 0.41, 0.41, 0.33};
    double s1[25] = {17.91,19,20,17.77,20,21.25,20,20,20,25.5,20,20,20,36.42,20,37.21,20,20,20,20,20,20,20,20,20};
    //double s2[25] = {16.12,15.89,20,15.23,20,15.68,20,20,20,21.13,20,20,20,37.01,20,39.28,20,20,20,20,20,20,20,20,20};
   // double sig = 20;
    double c[25];
    double sum = 0;
    for (int i = 0; i < 25; i++)
    {
        c[i] = br[i] * TMath::Gaus(x, energy[i], s1[i]);
        sum += c[i];
    }
    return sum;
}

// %%
double f2(double x)
{
    double energy[25] = {475, 721, 975, 1033, 1223, 1299, 1551, 1753, 2072, 2503, 2583, 2838, 3088, 3484, 4017, 4224, 4464, 4912, 5177, 5667, 5808, 5909, 6085, 6774, 7517};
    double br[25] = {4.73, 7.39, 0.25, 3, 0.75, 18.51, 0.81, 0.45, 0.48, 0.64, 4.89, 2.11/4, 1.89/3, 2.18/3, 1.078/2, 0.84/2, 3.21/2, 0.27/2, 0.29, 0.35, 0.18, 0.21, 0.41, 0.41, 0.33};
    //double s1[25] = {17.91,19,20,17.77,20,21.25,20,20,20,25.5,20,20,20,36.42,20,37.21,20,20,20,20,20,20,20,20,20};
    double s2[25] = {16.12,15.89,20,15.23,20,15.68,20,20,20,21.13,20,20,20,37.01,20,39.28,20,20,20,20,20,20,20,20,20};
   // double sig = 20;
    double c[25];
    double sum = 0;
    for (int i = 0; i < 25; i++)
    {
        c[i] = br[i] * TMath::Gaus(x, energy[i], s2[i]);
        sum += c[i];
    }
    return sum;
}

// %%
void dis()
{
    TF1 *fa1 = new TF1("fa1", "f1(x)", 0, 8000);
    fa1->SetNpx(8000);
    TF1 *fa2 = new TF1("fa2","f2(x)",0,8000);
    fa2->SetNpx(8000);
    TFile *opf = new TFile("edis.root", "recreate");
    TH1F *h1 = new TH1F("energydis1", "energydis1", 8000, 0, 8000);
    h1->FillRandom("fa1", 10000000);
    h1->Write();
    TH1F *h2 = new TH1F("energydis2", "energydis2", 8000, 0, 8000);
    h2->FillRandom("fa2", 10000000);
    h2->Write();
    opf->Close();
}
dis();

// %% [markdown]
// ### 实验谱与模拟谱的对比

// %% [markdown]
// 将质子谱作为Gean4模拟的输入，获得输出文件`simu0804.root`。

// %%
TFile *s1=new TFile("simu0804.root");
TCanvas c1;

// %%
tree->Draw("de[2][0]*1000>>p2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0");
tree->Draw("de[2][1]*1000>>b2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0");
tree->Draw("de[2][2]*1000>>b2_002(2000,0,8000)","de[1][2]<0.01&&de[0][2]<0.01&&de[2][2]>0");

tree->Draw("de[2][0]*1000>>pr2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][0]>0");
tree->Draw("de[2][0]*1000>>pl2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][0]<=0");
tree->Draw("de[2][1]*1000>>br2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&vetz[2][1]>0");
tree->Draw("de[2][1]*1000>>bl2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&vetz[2][1]<=0");

tree->Draw("(de[2][0]+de[2][1])*1000>>bp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0");
tree->Draw("(de[2][0]+de[2][1])*1000>>brp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][1]>0");
tree->Draw("(de[2][0]+de[2][1])*1000>>blp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][1]<=0");

// %% [markdown]
// 各个能谱的标识说明：
// * p2_001：后Si的单质子谱
// * b2_001：后Si的单beta谱
// * pr2_001：后Si的向后逃逸的质子单谱
// * pl2_001：后Si的向左逃逸的质子单谱
// * br2_001：后Si的向右逃逸的beta单谱
// * bl2_001：后Si的向左逃逸的beta单谱
// * bp2_001：后Si的质子+beta叠加谱
// * brp2_001：后Si的质子+向右逃逸的beta叠加谱
// * blp2_001：后Si的质子+向左逃逸的beta叠加谱

// %% [markdown]
// 载入实验谱。实验谱中均加未添加veto反符合条件。

// %%
TFile *s2=new TFile("al.root");

// %% [markdown]
// 考虑β叠加效应。在下图中，实线为实验谱，虚线为模拟获得后Si的质子+beta叠加谱。相比于之前的谱，我们可以发现，通过降低3~5MeV附近的分支比，一定程度上能够使得模拟谱逼近于实验谱。但谱的形状依旧无法对上。

// %%
c1.Clear();
s1->cd();
bp2_001->Scale(0.01555);
bp2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":36896776,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1000.00007450581,"fY1":-80.0528212216274,"fX2":9000.00007450581,"fY2":720.475343279448,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":0.0695999989628791,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.589610735674954,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-1000.00007450581,"fPixeltoXk":-1000.00007450581,"fPixeltoX":14.3678163060512,"fAbsPixeltoYk":720.475343279448,"fPixeltoYk":-80.0528212216274,"fPixeltoY":-1.69603424682431,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":8000,"fUymax":640.42252205782,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":8000,"fY2":640.42252205782,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"bp2_001","fTitle":"(de[2][0]+de[2][1])*1000 {de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":2002,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":2000,"fXmin":0,"fXmax":8000,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":3487788,"fTsumw":3487030,"fTsumw2":3487030,"fTsumwx":5669963762.18771,"fTsumwx2":15155167068312.1,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,0.430892055,0.4108224475,0.4127568675,0.4088880275,0.4108224475,0.4238797825,0.4352445,0.435728105,0.4449166,0.47199848,0.478285345,0.4596665525,0.4983549525,0.48167058,0.50391641,0.4770763325,0.49521152,0.4819123825,0.5075434475,0.5029492,0.51165409,0.5027073975,0.531481895,0.53873597,0.5210843875,0.54937528,0.553727725,0.5549367375,0.571137505,0.55904738,0.5718629125,0.604989855,0.643678255,0.6091004975,0.608 ...

// %% [markdown]
// 下图为先前所做的图，黑色线为保持原来的分支比做出的图。
// ![](https://i.loli.net/2019/08/05/WMw75niR9zBVlpH.png)

// %% [markdown]
// 通过这一步的调节可以发现一点，调整分支比之后依旧不能解决的一点是尖峰和鼓包的比例对不上，就导致即使调整分支比，也与实验谱不能良好地对齐。或许考虑增加峰的宽度？接下来可以试一试。
