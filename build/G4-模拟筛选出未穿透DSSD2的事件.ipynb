// %% [markdown]
// 为了和实验上进行对照，应该在模拟上添加veto探测器。简便起见，先筛选出未穿透最后一块Si的事件。

// %% [markdown]
// ### 质子峰宽度调整

// %%
%jsroot on
TFile *s1=new TFile("simu0720.root");
TCanvas c1;

// %%
tree->Draw("de[2][0]*1000>>p2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&dz[2][0]<38.304");
tree->Draw("de[2][1]*1000>>b2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&dz[2][1]<38.304");
tree->Draw("de[2][2]*1000>>b2_002(2000,0,8000)","de[1][2]<0.01&&de[0][2]<0.01&&de[2][2]>0&&dz[2][2]<38.304");
tree->Draw("(de[2][2]-de[2][1])*1000>>b2dif(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&de[2][2]>de[2][1]&&dz[2][1]<38.304");

tree->Draw("de[2][0]*1000>>pr2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][0]>0&&dz[2][0]<38.304");
tree->Draw("de[2][0]*1000>>pl2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][0]<=0&&dz[2][0]<38.304");
tree->Draw("de[2][1]*1000>>br2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&vetz[2][1]>0&&dz[2][1]<38.304");
tree->Draw("de[2][1]*1000>>bl2_001(2000,0,8000)","de[1][1]<0.01&&de[0][1]<0.01&&de[2][1]>0&&vetz[2][1]<=0&&dz[2][1]<38.304");

tree->Draw("(de[2][0]+de[2][1])*1000>>bp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&dz[2][0]<38.304&&dz[2][1]<38.304");
tree->Draw("(de[2][0]+de[2][1])*1000>>brp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][1]>0&&dz[2][0]<38.304&&dz[2][1]<38.304");
tree->Draw("(de[2][0]+de[2][1])*1000>>blp2_001(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][1]<=0&&dz[2][0]<38.304&&dz[2][1]<38.304");

tree->Draw("(de[2][0]+de[2][2])*1000>>bp2_002(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&dz[2][0]<38.304&&dz[2][2]<38.304");
tree->Draw("(de[2][0]+de[2][2])*1000>>brp2_002(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][2]>0&&dz[2][0]<38.304&&dz[2][2]<38.304");
tree->Draw("(de[2][0]+de[2][2])*1000>>blp2_002(2000,0,8000)","de[1][0]<0.01&&de[0][0]<0.01&&de[2][0]>0&&vetz[2][2]<=0&&dz[2][0]<38.304&&dz[2][2]<38.304");

// %% [markdown]
// 向右逃逸的峰位偏移100keV。

// %%
c1.Clear();
c1.Divide(1,2);
c1.cd(1);
bp2_001->SetLineColor(1);
brp2_001->SetLineColor(2);
blp2_001->SetLineColor(3);
p2_001->Draw();
bp2_001->Draw("same");
brp2_001->Draw("same");
blp2_001->Draw("same");
c1.cd(2);
bp2_002->SetLineColor(1);
brp2_002->SetLineColor(2);
blp2_002->SetLineColor(3);
p2_001->Draw();
bp2_002->Draw("same");
brp2_002->Draw("same");
blp2_002->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %% [markdown]
// 最高峰的计数对应的为纯质子峰，黑线为β叠加谱。绿线对β向左逃逸的β叠加谱，红线为β向右逃逸的β叠加谱。红线的锋味右移了100keV。由于之前分析过不同Q值下沉积的β能一致，因而不同峰偏移的程度应该一致。

// %%
TFile *s2=new TFile("al.root");

// %% [markdown]
// 峰位右移了14keV，峰宽变高。

// %%
c1.Clear();
s1->cd();
p2_001->Scale(0.006667);
p2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_2"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
c1.Clear();
s1->cd();
bp2_001->Scale(0.01875);
bp2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_3"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
c1.Clear();
s2->cd();
al2->Draw();
s1->cd();
brp2_001->Scale(0.015);
brp2_001->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_4"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
c1.Clear();
s1->cd();
blp2_001->Scale(0.01935);
blp2_001->Draw();
s2->cd();
al2->Draw("same");
c1.Draw();
// Out:
// <div id="root_plot_5"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %% [markdown]
// 可以看出，添加veto探测器后，明显伴峰得到了消除。注意1.3MeV处的质子峰，相比未添加质子峰，更贴近于实验。
